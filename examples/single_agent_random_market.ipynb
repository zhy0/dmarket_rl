# %%
import pandas as pd
import numpy as np

from stable_baselines import A2C, DQN
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv

from dmarket.environments import SingleAgentTrainingEnv
from dmarket.agents import UniformRandomAgent, GymRLAgent
from dmarket.info_settings import OfferInformationSetting
from dmarket.engine import MarketEngine

# %% [markdown]
# Let's create a training environment for baselines with 5 fixed buyers and sellers and 1 RL agent to be trained

# %%
fixed_agents = [
    UniformRandomAgent('seller', 90),
    UniformRandomAgent('seller', 90),
    UniformRandomAgent('seller', 90),
    UniformRandomAgent('seller', 90),
    UniformRandomAgent('seller', 90),
    UniformRandomAgent('buyer', 110),
    UniformRandomAgent('buyer', 110),
    UniformRandomAgent('buyer', 110),
    UniformRandomAgent('buyer', 110),
    UniformRandomAgent('buyer', 110),
]

rl_agent = GymRLAgent('buyer', 110, discretization=20)
setting = OfferInformationSetting(5)

def get_env(rl_agent, fixed_agents, setting):
    return SingleAgentTrainingEnv(rl_agent, fixed_agents, setting)

env = DummyVecEnv([lambda: get_env(rl_agent, fixed_agents, setting)]) # wrap it for baselines

# %% [markdown]
# Initialize a deep-Q RL model with MLP policy and high learning rate:

# %%
model = DQN("MlpPolicy", env, verbose=1, learning_rate=0.05)

# %%
# %%time
model.learn(total_timesteps=10000)
# Out:
# --------------------------------------
# | % time spent exploring  | 48       |
# | episodes                | 100      |
# | mean 100 episode reward | 6.3      |
# | steps                   | 527      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 5        |
# | episodes                | 200      |
# | mean 100 episode reward | 5.8      |
# | steps                   | 967      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300      |
# | mean 100 episode reward | 7.3      |
# | steps                   | 1124     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 400      |
# | mean 100 episode reward | 10.5     |
# | steps                   | 1380     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 500      |
# | mean 100 episode reward | 11.1     |
# | steps                   | 1825     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 600      |
# | mean 100 episode reward | 10.1     |
# | steps                   | 2695     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 700      |
# | mean 100 episode reward | 12.6     |
# | steps                   | 3517     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 800      |
# | mean 100 episode reward | 12.9     |
# | steps                   | 4234     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 900      |
# | mean 100 episode reward | 12.9     |
# | steps                   | 4895     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1000     |
# | mean 100 episode reward | 12.2     |
# | steps                   | 5473     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1100     |
# | mean 100 episode reward | 13.5     |
# | steps                   | 6127     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1200     |
# | mean 100 episode reward | 13.1     |
# | steps                   | 6579     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1300     |
# | mean 100 episode reward | 13.9     |
# | steps                   | 7171     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1400     |
# | mean 100 episode reward | 13.7     |
# | steps                   | 7783     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1500     |
# | mean 100 episode reward | 13.8     |
# | steps                   | 8296     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1600     |
# | mean 100 episode reward | 12.1     |
# | steps                   | 8774     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1700     |
# | mean 100 episode reward | 13.1     |
# | steps                   | 9395     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 1800     |
# | mean 100 episode reward | 13.4     |
# | steps                   | 9931     |
# --------------------------------------
# CPU times: user 53.3 s, sys: 3.61 s, total: 57 s
# Wall time: 31.8 s

# %% [markdown]
# Let's put this agent to the test

# %%
rl_agent.model = model

# %%
def get_reward(agent, deals):
    if not agent.name in deals:
        return 0

    deal_price = deals[agent.name]
    if agent.role == 'buyer':
        return agent.reservation_price - deal_price
    else:
        return deal_price - agent.reservation_price

def play_games(agents, setting, n_games=100, max_steps=30):
    buyer_ids =  [
        agent.name
        for agent in agents
        if agent.role == 'buyer'
    ]
    seller_ids =  [
        agent.name
        for agent in agents
        if agent.role == 'seller'
    ]
    ids = set(buyer_ids + seller_ids)
    market = MarketEngine(buyer_ids, seller_ids, max_steps=max_steps)
    
    rewards = pd.DataFrame(0, index=np.arange(n_games), columns=ids)
    for game_idx in range(n_games):
        while market.done != ids:
            observations = setting.get_states(ids, market)
            unmatched_agents = [
                agent for agent in agents
                if agent.name not in market.done
            ]
            offers = {
                agent.name: agent.get_offer(observations[agent.name])
                for agent in unmatched_agents
            }
            deals = market.step(offers)
            for agent in unmatched_agents:
                rewards[agent.name][game_idx] = get_reward(agent, deals)
        market.reset()
    return rewards

# %% [markdown]
# In this simple situation, the agent can get decent rewards:

# %%
play_games(fixed_agents + [rl_agent], setting, 10)
# Out:
#    Unif_S90_da0e  Unif_B110_8441  Unif_S90_78b0  Unif_S90_5c86  \
# 0             11              14              5             10
# 1             11               0             15              5
# 2              6              11              8              9
# 3             10               0             10              6
# 4             11              10              8              3
# 5              7              10              6              7
# 6             10               3             12              7
# 7             10               6             13              6
# 8             11              15              7              4
# 9             15               5             10              3
#
#    Unif_B110_ed92  GymR_B110_9e2b  Unif_B110_1200  Unif_S90_d60b  \
# 0               9              15               8              6
# 1               8              14               4              9
# 2              13              15               1              4
# 3               9              16              13              3
# 4              13              16               8              9
# 5              12              15              12              9
# 6               7               0               9              4
# 7               0              13               9              9
# 8               5               0              12             11
# 9              16              16               4             14
#
#    Unif_S90_499d  Unif_B110_5ed6  Unif_B110_8e30
# 0              4               0              13
# 1              5              10              14
# 2             18              10               0
# 3             10               9               9
# 4              6               0              11
# 5              4              13               0
# 6             16              12              15
# 7              5              14              10
# 8             14               8               8
# 9              3               0               9

# %%
play_games(fixed_agents + [rl_agent], setting, 100).describe()
# Out:
#        Unif_S90_da0e  Unif_B110_8441  Unif_S90_78b0  Unif_S90_5c86  \
# count     100.000000      100.000000     100.000000     100.000000
# mean        8.360000        6.900000       8.700000       8.830000
# std         3.825803        5.244526       3.597137       3.819289
# min         0.000000        0.000000       3.000000       0.000000
# 25%         5.750000        0.000000       6.000000       5.750000
# 50%         8.000000        8.000000       9.000000       9.000000
# 75%        11.000000       11.000000      11.000000      11.250000
# max        17.000000       18.000000      18.000000      18.000000
#
#        Unif_B110_ed92  GymR_B110_9e2b  Unif_B110_1200  Unif_S90_d60b  \
# count      100.000000      100.000000      100.000000     100.000000
# mean         7.720000       13.390000        8.060000       7.990000
# std          4.813869        4.334254        4.737173       3.445081
# min          0.000000        0.000000        0.000000       2.000000
# 25%          5.000000       14.000000        5.000000       5.000000
# 50%          9.000000       15.000000        9.000000       8.000000
# 75%         11.000000       15.000000       11.000000      10.000000
# max         19.000000       16.000000       18.000000      19.000000
#
#        Unif_S90_499d  Unif_B110_5ed6  Unif_B110_8e30
# count     100.000000      100.000000       100.00000
# mean        8.920000        7.760000         7.61000
# std         4.046897        4.807654         4.18727
# min         0.000000        0.000000         0.00000
# 25%         6.000000        4.000000         5.00000
# 50%         9.000000        9.000000         9.00000
# 75%        11.250000       11.250000        10.25000
# max        17.000000       16.000000        17.00000

# %% [markdown]
# Let's see if it can act as a seller as well:

# %%
rl_seller = GymRLAgent('seller', 90, model=model, name='myseller')

# %%
play_games(fixed_agents + [rl_seller], setting, 100).describe()
# Out:
#        Unif_S90_da0e  Unif_B110_8441  Unif_S90_78b0    myseller  \
# count     100.000000      100.000000     100.000000  100.000000
# mean        7.360000        9.290000       7.080000   11.670000
# std         4.639575        3.382352       4.423719    3.853517
# min         0.000000        4.000000       0.000000    0.000000
# 25%         3.750000        7.000000       5.000000   12.000000
# 50%         8.000000        9.000000       8.000000   13.000000
# 75%        10.250000       11.000000      10.000000   14.000000
# max        16.000000       18.000000      14.000000   15.000000
#
#        Unif_S90_5c86  Unif_B110_ed92  Unif_B110_1200  Unif_S90_d60b  \
# count     100.000000      100.000000      100.000000     100.000000
# mean        6.780000        9.290000        9.050000       8.050000
# std         4.569508        3.343303        3.854356       4.515685
# min         0.000000        2.000000        0.000000       0.000000
# 25%         3.000000        7.000000        6.000000       5.000000
# 50%         7.000000        9.000000        9.000000       9.000000
# 75%        10.000000       12.000000       11.250000      11.000000
# max        19.000000       17.000000       18.000000      18.000000
#
#        Unif_S90_499d  Unif_B110_5ed6  Unif_B110_8e30
# count      100.00000      100.000000      100.000000
# mean         7.07000        9.770000        9.400000
# std          5.19762        3.979379        3.200379
# min          0.00000        3.000000        1.000000
# 25%          0.75000        6.000000        7.000000
# 50%          8.00000       10.000000        9.000000
# 75%         11.25000       13.000000       11.000000
# max         17.00000       18.000000       19.000000

# %% [markdown]
# We see it performs slightly worse.
